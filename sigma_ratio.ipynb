# %%
# %matplotlib inline 
import numpy as np 
import matplotlib.pyplot as plt

# %%
sigma_all = np.load('files/sigma_all.npy')
sigma_9  = np.load('files/sigma_9.npy')
sigma_10 = np.load('files/sigma_10.npy')
sigma_11 = np.load('files/sigma_11.npy')
sigma_12 = np.load('files/sigma_12.npy')
sigma_13 = np.load('files/sigma_13.npy')
sigma_14 = np.load('files/sigma_14.npy')
sigma_15 = np.load('files/sigma_15.npy')
sigma_16 = np.load('files/sigma_16.npy')
sigma_17 = np.load('files/sigma_17.npy')
sigma_18 = np.load('files/sigma_18.npy')
sigma_19 = np.load('files/sigma_19.npy')
sigma_20 = np.load('files/sigma_20.npy')
sigma_21 = np.load('files/sigma_21.npy')
sigma_22 = np.load('files/sigma_22.npy')
sigma_23 = np.load('files/sigma_23.npy')

# %%
from glob import glob
lsst = glob('../Baryons_EiflerData/data_Eifler/storeThe_LSST/*LSST*')
for i in range(len(lsst)):
    print lsst[i]
# Out:
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/WDENS_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/WML4_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/NOSN_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/WML1V848_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/REF_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/AGN_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/DMonly_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/NOZCOOL_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/NOSN_NOZCOOL_LSST_shear_tomo_CL_model_1
# ../Baryons_EiflerData/data_Eifler/storeThe_LSST/DBLIMFV1618_LSST_shear_tomo_CL_model_1

# %%
case = 'lsst'

fullell = np.load('../Baryons_EiflerData/savedfiles/ell.npy')
fulldelta_all = np.load('../Baryons_EiflerData/data_Eifler/delta%s.npy'%case)

# %%
fulldelta = fulldelta_all[:,[1,2,4,5,6,7,8,9,10]]

# %%
# Creates an array that holds all delta's from the sims
#case = 'lsst'

lsst_names = [ 'OWLS-AGN', 'ART14-CW', 'OWLS-DBLIMFV', 'OWLS-NOSN', \
              'OWLS-NOSN-NOZCOOL', 'OWLS-NOZCOOL', 'OWLS-REF', 'OWLS-WDENS', \
              'OWLS-WML1V848']

ell = fullell[:12]

delta_tg512_41 = np.load('files/delta_tg512_41.npy')
delta_tg512_42 = np.load('files/delta_tg512_42.npy')
delta_tg512_43 = np.load('files/delta_tg512_43.npy')
delta_tg512_53 = np.load('files/delta_tg512_53.npy')
delta_tg512_63 = np.load('files/delta_tg512_63.npy')
delta_tg512_73 = np.load('files/delta_tg512_73.npy')
delta_tg512_00 = np.load('files/delta_tg512_00.npy')
delta_tg512_363 = np.load('files/delta_tg512_363.npy')
delta_tg512_62 = np.load('files/delta_tg512_62.npy')
delta_tg512_72 = np.load('files/delta_tg512_72.npy')
delta_tg512_23 = np.load('files/delta_tg512_23.npy')
delta_tg512_33 = np.load('files/delta_tg512_33.npy')
delta_tg512_61 = np.load('files/delta_tg512_61.npy')
delta_tg512_22 = np.load('files/delta_tg512_22.npy')
delta_tg512_51 = np.load('files/delta_tg512_51.npy')

# %%
# puts all the sims in a list
deltadata = []
for i in range(len(lsst_names)):
    deltadata.append(fulldelta[:,i])

deltadata.append(delta_tg512_41)
deltadata.append(delta_tg512_42)
deltadata.append(delta_tg512_43)
deltadata.append(delta_tg512_53)
deltadata.append(delta_tg512_63)
deltadata.append(delta_tg512_73)
deltadata.append(delta_tg512_00)
deltadata.append(delta_tg512_363)
deltadata.append(delta_tg512_62)
deltadata.append(delta_tg512_72)
deltadata.append(delta_tg512_23)
deltadata.append(delta_tg512_33)
deltadata.append(delta_tg512_61)
deltadata.append(delta_tg512_22)
deltadata.append(delta_tg512_51)

deltadata = np.array(deltadata)

# Put tags to all added simulations
names = lsst_names[:]

names.append('512:[1e4,1]')
names.append('512:[1e4,2]')
names.append('512:[1e4,3]')
names.append('512:[1e5,3]')
names.append('512:[1e6,3]')
names.append('512:[1e7,3]')
names.append('512:[0,0]')
names.append('512:[3e6,3]')
names.append('512:[1e6,2]')
names.append('512:[1e7,2]')
names.append('512:[1e2,3]')
names.append('512:[1e3,3]')
names.append('512:[1e6,1]')
names.append('512:[1e2,2]')
names.append('512:[1e5,1]')

names = np.array(names, dtype=str)

print "full data shape: ", deltadata.shape

# Plot the delta's for all the simulation data uploaded to deltadata
# No fitting yet, just pre-processing of data
deltadata.shape

plt.figure(figsize=(15,10))
for i in range(len(deltadata)):
    if 'OWLS' in names[i]:
        ls='-'
    elif 'ART14' in names[i]:
        ls='-'
    elif 'HC' in names[i]:
        ls='-.'
    elif 'TG' in names[i]:
        ls=':' 
    elif '512' in names[i]:
        ls='--'
    plt.semilogx(ell, deltadata[i, :12], ls=ls, lw=2, label='$\mathtt{%i:%s}$'%(i, names[i]))
lgd = plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=22)
plt.xlabel('$\mathtt{\ell}$', fontsize=22)
plt.ylabel('$\mathtt{C^{\ell}_{BAR}/C^{\ell}_{DMO}-1}$', fontsize=22)
plt.title('$\mathtt{LSST: \ Auto\ Spectra: (0,0)}$', fontsize=22)
plt.axhline(y=0, ls='-', c='k', lw=0.5)
# Out:
# full data shape:  (24, 180)

# %%
print 'sigma_all = ', sigma_all
print
print 'sigma_9   = ', sigma_9
print 'sigma_10  = ', sigma_10
print 'sigma_11  = ', sigma_11
print 'sigma_12  = ', sigma_12
print 'sigma_13  = ', sigma_13
print 'sigma_14  = ', sigma_14
print 'sigma_15  = ', sigma_15
print 'sigma_16  = ', sigma_16
print 'sigma_17  = ', sigma_17
print 'sigma_18  = ', sigma_18
print 'sigma_19  = ', sigma_19
print 'sigma_20  = ', sigma_20
print 'sigma_21  = ', sigma_21
print 'sigma_22  = ', sigma_22
print 'sigma_23  = ', sigma_23
# Out:
# sigma_all =  0.00433336245902
#
# sigma_9   =  0.00430941806998
# sigma_10  =  0.00434602536862
# sigma_11  =  0.0042750672783
# sigma_12  =  0.00429497860882
# sigma_13  =  0.00428308879249
# sigma_14  =  0.00429607551206
# sigma_15  =  0.00454184194872
# sigma_16  =  0.00428834069623
# sigma_17  =  0.00429075524974
# sigma_18  =  0.00430219304525
# sigma_19  =  0.00432017788144
# sigma_20  =  0.00431331378038
# sigma_21  =  0.00428730658249
# sigma_22  =  0.00432012380342
# sigma_23  =  0.00430920494037

# %%
ratio_9  = sigma_all/sigma_9
ratio_10 = sigma_all/sigma_10
ratio_11 = sigma_all/sigma_11
ratio_12 = sigma_all/sigma_12
ratio_13 = sigma_all/sigma_13
ratio_14 = sigma_all/sigma_14
ratio_15 = sigma_all/sigma_15
ratio_16 = sigma_all/sigma_16
ratio_17 = sigma_all/sigma_17
ratio_18 = sigma_all/sigma_18
ratio_19 = sigma_all/sigma_19
ratio_20 = sigma_all/sigma_20
ratio_21 = sigma_all/sigma_21
ratio_22 = sigma_all/sigma_22
ratio_23 = sigma_all/sigma_23

# %%
print 'ratio_9   = ', ratio_9
print 'ratio_10  = ', ratio_10
print 'ratio_11  = ', ratio_11
print 'ratio_12  = ', ratio_12
print 'ratio_13  = ', ratio_13
print 'ratio_14  = ', ratio_14
print 'ratio_15  = ', ratio_15
print 'ratio_16  = ', ratio_16
print 'ratio_17  = ', ratio_17
print 'ratio_18  = ', ratio_18
print 'ratio_19  = ', ratio_19
print 'ratio_20  = ', ratio_20
print 'ratio_21  = ', ratio_21
print 'ratio_22  = ', ratio_22
print 'ratio_23  = ', ratio_23
# Out:
# ratio_9   =  1.0055562929
# ratio_10  =  0.997086324051
# ratio_11  =  1.01363608498
# ratio_12  =  1.00893691301
# ratio_13  =  1.01173771289
# ratio_14  =  1.00867930437
# ratio_15  =  0.9540980307
# ratio_16  =  1.01049864411
# ratio_17  =  1.00993000225
# ratio_18  =  1.00724500585
# ratio_19  =  1.00305185989
# ratio_20  =  1.00464809185
# ratio_21  =  1.01074238001
# ratio_22  =  1.00306441579
# ratio_23  =  1.00560602686

# %%
sigma_delta = []

sigma_delta.append(sigma_all)
sigma_delta.append(sigma_9)
sigma_delta.append(sigma_10)
sigma_delta.append(sigma_11)
sigma_delta.append(sigma_12)
sigma_delta.append(sigma_13)
sigma_delta.append(sigma_14)
sigma_delta.append(sigma_15)
sigma_delta.append(sigma_16)
sigma_delta.append(sigma_17)
sigma_delta.append(sigma_18)
sigma_delta.append(sigma_19)
sigma_delta.append(sigma_20)
sigma_delta.append(sigma_21)
sigma_delta.append(sigma_22)
sigma_delta.append(sigma_23)

print type(sigma_delta)

sigmas = np.asarray(sigma_delta)
# Out:
# <type 'list'>

# %%
ratio_delta = []

ratio_delta.append(ratio_9)
ratio_delta.append(ratio_10)
ratio_delta.append(ratio_11)
ratio_delta.append(ratio_12)
ratio_delta.append(ratio_13)
ratio_delta.append(ratio_14)
ratio_delta.append(ratio_15)
ratio_delta.append(ratio_16)
ratio_delta.append(ratio_17)
ratio_delta.append(ratio_18)
ratio_delta.append(ratio_19)
ratio_delta.append(ratio_20)
ratio_delta.append(ratio_21)
ratio_delta.append(ratio_22)
ratio_delta.append(ratio_23)

print type(ratio_delta)

ratios = np.asarray(ratio_delta)
# Out:
# <type 'list'>

# %%
print sigmas
print ratios
# Out:
# [ 0.00433336  0.00430942  0.00434603  0.00427507  0.00429498  0.00428309
#   0.00429608  0.00454184  0.00428834  0.00429076  0.00430219  0.00432018
#   0.00431331  0.00428731  0.00432012  0.0043092 ]
# [ 1.00555629  0.99708632  1.01363608  1.00893691  1.01173771  1.0086793
#   0.95409803  1.01049864  1.00993     1.00724501  1.00305186  1.00464809
#   1.01074238  1.00306442  1.00560603]

# %%
(ratios -1)*100
# Out:
# array([ 0.55562929, -0.29136759,  1.3636085 ,  0.8936913 ,  1.17377129,
#         0.86793044, -4.59019693,  1.04986441,  0.99300022,  0.72450058,
#         0.30518599,  0.46480919,  1.074238  ,  0.30644158,  0.56060269])

# %%
np.save('files/sigmas', sigmas)
np.save('files/ratios', ratios)
